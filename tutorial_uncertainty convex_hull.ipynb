# %% [markdown]
# # Hello World under Uncertainty!
# In this notebook, we will use the **FoSRL** library to train a safe policy in a uncertain control-affine system.
#
# We consider a linear dynamical system with additive uncertainty:
# $$
# \dot{x} = A \, x + B \, u + z
# $$
#
# where `x=[px, py]`, `u=[vx, vy]` and `z=[zx, zy]`.
#
# As already shown in the previous tutorial, FoSRL operates in two distinct phases:
#
# 1. An **offline counter-example guided pretraining** phase, where FoSRL is going to build a Control Barrier Function (CBF) to remain within the set of safe states.
# 2. An **online safe interactive learning** phase, where FoSRL is going to iteratively (and safely) explore the environment, collect the reward signal, and update the policy to maximize the reward collection.
#
# The changes to cope with uncertainty mainly affect the first phase, while the second remains the same as in the previous tutorial.

# %%
import matplotlib.pyplot as plt
# Import the necessary libraries
import numpy as np
import torch
from fosco.systems import make_system
from fosco.systems.uncertainty import add_uncertainty
from fosco.config import CegisConfig
from fosco.cegis import Cegis

# plotting utilities
from fosco.plotting.domains import plot_domain
from fosco.plotting.constants import DOMAIN_COLORS
from plotly.graph_objs import Figure

# %%
seed = 42
verbosity = 1

# %% [markdown]
# # Offline Counter-example guided Pretraining

# %% [markdown]
# ### Define the symbolic assumptions on the dynamics and uncertainty
#
# To enable the counter-example guided pretraining,
# we need to define a set of **symbolic assumptions** on the environment dynamics
# that we use to learn and verify the CBF.
#
# For all systems,
# the assumptions consist of the characterization of the state and spaces,
# and sub-domains for initial, unsafe and other states.
# Moreover,
# since we are considering an uncertain system,
# we need to define the uncertainty domain.
#
# Each domain must be a **symbolic set**.
# We offer several implementations of common multi-dimensional sets,
# such as:
# - Rectangle, Sphere,
# - Union, Intersection, Complement,
# - and others.

# %%
from fosco.models import TorchSymFn

# we are instaniating this class one by one, or by batch?
class UncertainFunc(TorchSymFn):
    def __init__(self, uncertain_func) -> None:
        super().__init__()
        self.uncertain_func = uncertain_func

    # TODO
    def input_size(self) -> int:
        raise NotImplementedError

    def output_size(self) -> int:
        raise NotImplementedError

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """
        Input x: shape is (batch_size, state_dim) or (batch_size, state_dim, 1)
        """
        if len(x.size()) == 3:
            x = torch.squeeze(x, dim=2)
        return (x * torch.tensor(self.uncertain_func)).unsqueeze(dim=2)

    def forward_smt(self, x: list) -> list | np.ndarray:
        return np.array(self.uncertain_func) * np.array(x)

# %%
# define control-affine dynamical system
system_id = "SingleIntegrator"
uncertainty_id = "ConvexHull"
verbose = 1

uncertain_func_list = [
    [0.2, 0.2],
    [0.3, 0.2],
    [0.5, 0.1],
]  # define uncertain function to be linear
f_uncertainty = []
for uncertain_func in uncertain_func_list:
    f_uncertainty.append(UncertainFunc(uncertain_func))

system = make_system(system_id=system_id)()
system = add_uncertainty(
    uncertainty_type=uncertainty_id,
    system=system,
    f_uncertainty=f_uncertainty,
)
print(type(system))
# Out:
# <class 'fosco.systems.uncertainty.convex_hull.ConvexHull'>

# %%
# define state domains and input domains
# and initial, unsafe, lie state domains
domains = system.domains

print("Domains: ", list(domains.keys()), "\n")
for k, dom in domains.items():
    print(f"{k}: {dom}")

# Visualization of state domains
fig = Figure()
for dname, domain in domains.items():
    if dname in DOMAIN_COLORS:        
        color = DOMAIN_COLORS[dname] if dname in DOMAIN_COLORS else None
        fig = plot_domain(domain, fig, color=color, label=dname)
fig.update_traces(showlegend=True)

fig.show()
# Out:
# Domains:  ['lie', 'input', 'init', 'unsafe', 'uncertainty']
#
# lie: Rectangle((-5.0, -5.0), (5.0, 5.0))
# input: Rectangle((-5.0, -5.0), (5.0, 5.0))
# init: Complement(Rectangle((-4.0, -4.0), (4.0, 4.0)))
# unsafe: Sphere((0.0, 0.0), 1.0)
# uncertainty: SumToOneSet['z0', 'z1', 'z2']

# %% [markdown]
# For this system, there are now five domains:
# - `input`: the domain of control actions;
# - **`uncertainty`: the domain of the uncertainty.**
# - `init`: the domain of initial states, for which we want the CBF to be positive;
# - `unsafe`: the domain of unsafe states, for which we want the CBF to be negative;
# - `lie`: the domain of all the states, for which we will try to enforce the CBF condition on Lie derivative.

# %% [markdown]
# ### Define the numerical data
#
# Having defined the symbolic expressions for the verification of the CBF,
# we need their numerical counter-parts to have training data for the learning.
#
# Here, for each of the state domains,
# we are going to define a dataset of samples:
# - `init`: a dataset of initial states;
# - `unsafe`: a dataset of unsafe states;
# - `lie`: a dataset of (state, action) pairs.
#
# Note: we do not directly define the training data,
# because the tool expects to get generator functions for each of them.

# %%
# data generator
from fosco.common.consts import DomainName as dn

data_gen = {
    'init': lambda n: domains[dn.XI.value].generate_data(n),
    'unsafe': lambda n: domains[dn.XU.value].generate_data(n),
    'lie': lambda n: torch.concatenate([
        domains["lie"].generate_data(n), 
        domains["input"].generate_data(n),
        domains["uncertainty"].generate_data(n),
    ], dim=1
    ),
    'uncertainty': lambda n: torch.concatenate([
        domains["lie"].generate_data(n),
        domains["input"].generate_data(n),
        domains["uncertainty"].generate_data(n),
    ],
    dim=1,
    )
}

# %% [markdown]
# ### Define the configuration
#
# It remains to define the configuration of the pretraining and its hyper-parameters.
#
# There are two important changes to the configuration:
# - the `CERTIFICATE` is now set to `rcbf` to indicate we are looking for a Robust CBF;
# - the `LOSS_WEIGHTS` includes the uncertainty loss term and an additional regularization term.

# %%
config = CegisConfig(
    SEED=seed,              # the seed for reproducibility
    CERTIFICATE="rcbf",      # the type of certificate, either cbf or rcbf
    VERIFIER="z3",          # the type of verifier, either z3 or dreal
    ACTIVATION=["htanh"],   # the activation of the i-th hidden layer
    N_HIDDEN_NEURONS=[20],  # the nr of neurons of the i-th hidden layer
    CEGIS_MAX_ITERS=20,     # the maximum number of iterations
    N_DATA=5000,            # the nr of samples in each training dataset
    RESAMPLING_N=100,       # the nr of points to sample around each counter-example
    RESAMPLING_STDDEV=0.1,  # the std deviation to sample around each counter-example    
    LOSS_WEIGHTS={          # the weights for each loss term
        'init': 1.0, 
        'unsafe': 1.0, 
        'lie': 1.0,
        'robust': 1.0,
        'conservative_b': 1.0,
        'conservative_sigma': 0.1        
    },
)

# %% [markdown]
# Let us spend some words on the loss weights.
#
# For finding a candidate CBF, we minimize the following loss
#
# $$
# \mathcal{L} = \lambda_{init} \, \mathcal{L}_{init} + \lambda_{unsafe} \, \mathcal{L}_{unsafe} + \lambda_{lie} \, \mathcal{L}_{lie} + \lambda_{robust} \, \mathcal{L}_{robust} + \lambda_{reg-b} \, \mathcal{L}_{reg-b} + \lambda_{reg-s} \, \mathcal{L}_{reg-s}
# $$
#
# where:
# - $\mathcal{L}_{init}$ penalizes counter-examples in the dataset of initial states;
# - $\mathcal{L}_{unsafe}$ penalizes counter-examples in the dataset of unsafe states;
# - $\mathcal{L}_{lie}$ penalizes counter-examples in the lie dataset;
# - $\mathcal{L}_{robust}$ penalizes counter-examples in the robust dataset;
# - $\mathcal{L}_{reg-b}$ penalizes states where the CBF is negative, to discourage overconservative CBF functions.
# - $\mathcal{L}_{reg-s}$ penalizes states where the compensator is positive, to discourage overconservative compensator functions.

# %%
from fosco.plotting.functions import plot_torch_function

cegis = Cegis(
    system=system,
    domains=domains,
    config=config,
    data_gen=data_gen,
    verbose=verbosity
)

result = cegis.solve()


fig = plot_torch_function(
    function=result.barrier, 
    domains=system.domains
)
fig.show()

fig = plot_torch_function(
    function=result.compensator, 
    domains=system.domains
)
fig.show()
# Out:
# (2,)
# 0 [z0, z1, z2] 3 3 [1/5*x0 1/5*x1]
# 1 [z0, z1, z2] 3 3 [3/10*x0 1/5*x1]
# 2 [z0, z1, z2] 3 3 [1/2*x0 1/10*x1]
# INFO:fosco.cegis:Seed: 42
# INFO:fosco.cegis:Iteration 1
# INFO:fosco.verifier.verifier:init: Counterexample Found: [x0, x1] = tensor([ 5.0000, -0.5841]), [] = tensor([])
# INFO:fosco.consolidator.consolidator:Dataset sizes: init: 5101, unsafe: 5000, lie: 5000, uncertainty: 5000
# INFO:fosco.cegis:
# INFO:fosco.cegis:Iteration 2
# INFO:fosco.verifier.verifier:init: Counterexample Found: [x0, x1] = tensor([-1.0759, -4.5048]), [] = tensor([])
# INFO:fosco.consolidator.consolidator:Dataset sizes: init: 5202, unsafe: 5000, lie: 5000, uncertainty: 5000
# INFO:fosco.cegis:
# INFO:fosco.cegis:Iteration 3
# INFO:fosco.verifier.verifier:init: Counterexample Found: [x0, x1] = tensor([-4.0471, -0.2644]), [] = tensor([])
# INFO:fosco.consolidator.consolidator:Dataset sizes: init: 5303, unsafe: 5000, lie: 5000, uncertainty: 5000
# INFO:fosco.cegis:
# INFO:fosco.cegis:Iteration 4
# INFO:fosco.verifier.verifier:init: Counterexample Found: [x0, x1] = tensor([ 0.1316, -5.0000]), [] = tensor([])
# INFO:fosco.consolidator.consolidator:Dataset sizes: init: 5404, unsafe: 5000, lie: 5000, uncertainty: 5000
# INFO:fosco.cegis:
# INFO:fosco.cegis:Iteration 5
# INFO:fosco.verifier.verifier:unsafe: Counterexample Found: [x0, x1] = tensor([0.0000, 0.8750]), [] = tensor([])
# INFO:fosco.consolidator.consolidator:Dataset sizes: init: 5404, unsafe: 5101, lie: 5000, uncertainty: 5000
# INFO:fosco.cegis:
# INFO:fosco.cegis:Iteration 6
# INFO:fosco.verifier.verifier:No counterexamples found!
# INFO:fosco.consolidator.consolidator:Dataset sizes: init: 5404, unsafe: 5101, lie: 5000, uncertainty: 5000
# INFO:fosco.cegis:CEG Pretraining finished after 6 iterations

# %% [markdown]
# # Online Safe Interactive Learning
#
# Starting from the Robust CBF found in the previous phase,
# we can now proceed with the policy training.

# %% [markdown]
# ### Gymnasium Wrapper
#
# As common in RL libraries, we adopt the `gymnasium` api to simulate the system.
#
# To make the continuous-time CBF formulation to work in discretized simulation,
# we use a small time step.

# %%
import gymnasium as gym
from fosco.systems.gym_env.system_env import SystemEnv
from fosco.systems.gym_env.rewards import GoToUnsafeReward
from rl_trainer.wrappers.record_episode_statistics import RecordEpisodeStatistics

max_steps = 100
sim_dt = 0.1
num_envs = 3

def make_env(seed, render_mode=None):

    def thunk():
        env = SystemEnv(
            system=system,
            dt=sim_dt,
            max_steps=max_steps,
            reward_fn=GoToUnsafeReward(system=system),
            render_mode=render_mode
        )
        env.action_space.seed(seed)
        env = RecordEpisodeStatistics(env)
        env = gym.wrappers.NormalizeReward(env)
        env = gym.wrappers.TransformReward(env, lambda reward: np.clip(reward, -10, 10))
        return env

    return thunk
    
envs = gym.vector.SyncVectorEnv(
        [
            make_env(seed=seed) for i in range(num_envs)
        ]
    )

# %% [markdown]
# ### Define Safe Policy

# %%
from rl_trainer.ppo.ppo_config import PPOConfig

config = PPOConfig()
config.num_envs = num_envs
config.num_steps = 256
config.total_timesteps = 100000

# %%
from rl_trainer.safe_ppo.safeppo_trainer import SafePPOTrainer

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
trainer = SafePPOTrainer(envs=envs, config=config, barrier=result.barrier, compensator=result.compensator, device=device)
# Out:
# /home/shuo/shuo_research/learn_verify_cbf/fosco/verify_cbf_env/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning:
#
# WARN: env.system to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.system` for environment variables or `env.get_wrapper_attr('system')` that will search the reminding wrappers.

# %% [markdown]
# ### Training

# %%
results = trainer.train(envs=envs, verbose=verbosity)
# Out:
# INFO:rl_trainer.ppo.ppo_trainer:iteration 1/130
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 103
# INFO:rl_trainer.ppo.ppo_trainer:iteration 2/130
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 107
# INFO:rl_trainer.ppo.ppo_trainer:iteration 3/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 1536/100000
# 	episodic returns: -566.98 +/- 82.22
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 109
# INFO:rl_trainer.ppo.ppo_trainer:iteration 4/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 2304/100000
# 	episodic returns: -499.77 +/- 87.86
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 110
# INFO:rl_trainer.ppo.ppo_trainer:iteration 5/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 3072/100000
# 	episodic returns: -564.33 +/- 60.70
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 110
# INFO:rl_trainer.ppo.ppo_trainer:iteration 6/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 3840/100000
# 	episodic returns: -575.16 +/- 124.54
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 110
# INFO:rl_trainer.ppo.ppo_trainer:iteration 7/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 4608/100000
# 	episodic returns: -560.17 +/- 111.20
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 111
# INFO:rl_trainer.ppo.ppo_trainer:iteration 8/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 5376/100000
# 	episodic returns: -525.42 +/- 90.87
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 111
# INFO:rl_trainer.ppo.ppo_trainer:iteration 9/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 6144/100000
# 	episodic returns: -493.21 +/- 97.26
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 112
# INFO:rl_trainer.ppo.ppo_trainer:iteration 10/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 6912/100000
# 	episodic returns: -571.09 +/- 100.03
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 112
# INFO:rl_trainer.ppo.ppo_trainer:iteration 11/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 7680/100000
# 	episodic returns: -507.89 +/- 111.60
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 112
# INFO:rl_trainer.ppo.ppo_trainer:iteration 12/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 8448/100000
# 	episodic returns: -484.05 +/- 57.65
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 112
# INFO:rl_trainer.ppo.ppo_trainer:iteration 13/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 9216/100000
# 	episodic returns: -470.78 +/- 70.68
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 112
# INFO:rl_trainer.ppo.ppo_trainer:iteration 14/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 9984/100000
# 	episodic returns: -491.79 +/- 108.00
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 112
# INFO:rl_trainer.ppo.ppo_trainer:iteration 15/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 10752/100000
# 	episodic returns: -541.36 +/- 97.74
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 112
# INFO:rl_trainer.ppo.ppo_trainer:iteration 16/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 11520/100000
# 	episodic returns: -458.06 +/- 116.59
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 112
# INFO:rl_trainer.ppo.ppo_trainer:iteration 17/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 12288/100000
# 	episodic returns: -414.40 +/- 90.84
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 112
# INFO:rl_trainer.ppo.ppo_trainer:iteration 18/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 13056/100000
# 	episodic returns: -407.35 +/- 71.28
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 112
# INFO:rl_trainer.ppo.ppo_trainer:iteration 19/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 13824/100000
# 	episodic returns: -458.66 +/- 105.35
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 112
# INFO:rl_trainer.ppo.ppo_trainer:iteration 20/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 14592/100000
# 	episodic returns: -454.66 +/- 108.98
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 112
# INFO:rl_trainer.ppo.ppo_trainer:iteration 21/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 15360/100000
# 	episodic returns: -448.58 +/- 57.43
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 112
# INFO:rl_trainer.ppo.ppo_trainer:iteration 22/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 16128/100000
# 	episodic returns: -484.61 +/- 81.16
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 112
# INFO:rl_trainer.ppo.ppo_trainer:iteration 23/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 16896/100000
# 	episodic returns: -471.42 +/- 86.85
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 112
# INFO:rl_trainer.ppo.ppo_trainer:iteration 24/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 17664/100000
# 	episodic returns: -466.54 +/- 114.14
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 112
# INFO:rl_trainer.ppo.ppo_trainer:iteration 25/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 18432/100000
# 	episodic returns: -499.58 +/- 114.35
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 112
# INFO:rl_trainer.ppo.ppo_trainer:iteration 26/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 19200/100000
# 	episodic returns: -455.93 +/- 115.55
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 27/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 19968/100000
# 	episodic returns: -392.39 +/- 69.43
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 28/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 20736/100000
# 	episodic returns: -431.89 +/- 105.11
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 29/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 21504/100000
# 	episodic returns: -391.37 +/- 93.40
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 30/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 22272/100000
# 	episodic returns: -468.34 +/- 118.66
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 31/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 23040/100000
# 	episodic returns: -404.11 +/- 141.79
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 32/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 23808/100000
# 	episodic returns: -375.65 +/- 124.75
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 33/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 24576/100000
# 	episodic returns: -344.56 +/- 90.54
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 34/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 25344/100000
# 	episodic returns: -398.59 +/- 77.07
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 35/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 26112/100000
# 	episodic returns: -296.95 +/- 53.53
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 36/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 26880/100000
# 	episodic returns: -284.64 +/- 42.93
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 37/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 27648/100000
# 	episodic returns: -282.97 +/- 33.21
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 38/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 28416/100000
# 	episodic returns: -252.90 +/- 42.70
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 39/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 29184/100000
# 	episodic returns: -252.16 +/- 31.78
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 40/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 29952/100000
# 	episodic returns: -238.25 +/- 28.65
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 41/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 30720/100000
# 	episodic returns: -251.03 +/- 28.66
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 42/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 31488/100000
# 	episodic returns: -239.64 +/- 27.66
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 43/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 32256/100000
# 	episodic returns: -225.50 +/- 19.74
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 44/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 33024/100000
# 	episodic returns: -227.91 +/- 16.11
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 45/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 33792/100000
# 	episodic returns: -223.69 +/- 19.36
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 46/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 34560/100000
# 	episodic returns: -210.86 +/- 12.39
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 47/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 35328/100000
# 	episodic returns: -214.34 +/- 17.18
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 48/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 36096/100000
# 	episodic returns: -214.42 +/- 12.06
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 49/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 36864/100000
# 	episodic returns: -223.60 +/- 29.59
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 50/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 37632/100000
# 	episodic returns: -206.10 +/- 8.84
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 51/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 38400/100000
# 	episodic returns: -205.46 +/- 11.90
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 52/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 39168/100000
# 	episodic returns: -207.77 +/- 14.01
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 53/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 39936/100000
# 	episodic returns: -209.54 +/- 15.62
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 54/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 40704/100000
# 	episodic returns: -204.08 +/- 15.48
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 55/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 41472/100000
# 	episodic returns: -207.52 +/- 13.54
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 56/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 42240/100000
# 	episodic returns: -200.73 +/- 12.27
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 57/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 43008/100000
# 	episodic returns: -195.27 +/- 10.65
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 58/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 43776/100000
# 	episodic returns: -192.79 +/- 8.51
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 59/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 44544/100000
# 	episodic returns: -197.63 +/- 7.67
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 60/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 45312/100000
# 	episodic returns: -205.25 +/- 8.70
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 61/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 46080/100000
# 	episodic returns: -198.09 +/- 8.74
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 62/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 46848/100000
# 	episodic returns: -192.68 +/- 7.35
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 63/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 47616/100000
# 	episodic returns: -189.78 +/- 7.85
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 64/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 48384/100000
# 	episodic returns: -192.25 +/- 9.88
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 65/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 49152/100000
# 	episodic returns: -192.28 +/- 9.51
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 66/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 49920/100000
# 	episodic returns: -184.30 +/- 4.71
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 67/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 50688/100000
# 	episodic returns: -191.11 +/- 9.79
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 68/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 51456/100000
# 	episodic returns: -189.39 +/- 8.34
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 69/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 52224/100000
# 	episodic returns: -185.46 +/- 6.23
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 70/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 52992/100000
# 	episodic returns: -184.54 +/- 6.09
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 71/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 53760/100000
# 	episodic returns: -183.95 +/- 8.51
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 72/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 54528/100000
# 	episodic returns: -187.20 +/- 7.18
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 73/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 55296/100000
# 	episodic returns: -188.47 +/- 8.83
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 74/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 56064/100000
# 	episodic returns: -187.66 +/- 11.22
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 75/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 56832/100000
# 	episodic returns: -182.21 +/- 9.39
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 76/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 57600/100000
# 	episodic returns: -182.41 +/- 13.27
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 77/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 58368/100000
# 	episodic returns: -182.79 +/- 10.18
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 78/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 59136/100000
# 	episodic returns: -179.26 +/- 5.03
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 79/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 59904/100000
# 	episodic returns: -179.15 +/- 5.45
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 80/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 60672/100000
# 	episodic returns: -182.02 +/- 6.33
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 81/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 61440/100000
# 	episodic returns: -181.84 +/- 7.19
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 82/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 62208/100000
# 	episodic returns: -175.97 +/- 5.50
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 83/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 62976/100000
# 	episodic returns: -175.60 +/- 3.70
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 84/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 63744/100000
# 	episodic returns: -180.03 +/- 6.55
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 85/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 64512/100000
# 	episodic returns: -175.52 +/- 6.21
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 86/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 65280/100000
# 	episodic returns: -177.57 +/- 9.64
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 87/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 66048/100000
# 	episodic returns: -178.00 +/- 7.36
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 88/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 66816/100000
# 	episodic returns: -174.91 +/- 5.72
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 89/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 67584/100000
# 	episodic returns: -175.98 +/- 6.22
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 90/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 68352/100000
# 	episodic returns: -173.23 +/- 7.59
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 91/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 69120/100000
# 	episodic returns: -175.81 +/- 6.20
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 92/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 69888/100000
# 	episodic returns: -175.81 +/- 5.96
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 93/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 70656/100000
# 	episodic returns: -172.82 +/- 6.36
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 94/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 71424/100000
# 	episodic returns: -176.11 +/- 7.15
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 95/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 72192/100000
# 	episodic returns: -173.76 +/- 6.39
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 96/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 72960/100000
# 	episodic returns: -174.19 +/- 5.69
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 97/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 73728/100000
# 	episodic returns: -172.35 +/- 5.37
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 98/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 74496/100000
# 	episodic returns: -169.12 +/- 4.67
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 99/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 75264/100000
# 	episodic returns: -174.77 +/- 6.52
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 100/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 76032/100000
# 	episodic returns: -171.36 +/- 5.88
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 101/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 76800/100000
# 	episodic returns: -173.72 +/- 5.91
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 102/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 77568/100000
# 	episodic returns: -172.34 +/- 4.23
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 103/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 78336/100000
# 	episodic returns: -171.89 +/- 3.19
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 104/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 79104/100000
# 	episodic returns: -170.10 +/- 3.27
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 105/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 79872/100000
# 	episodic returns: -170.38 +/- 4.73
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 106/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 80640/100000
# 	episodic returns: -172.35 +/- 6.20
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 107/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 81408/100000
# 	episodic returns: -172.31 +/- 7.10
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 108/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 82176/100000
# 	episodic returns: -174.02 +/- 4.75
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 109/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 82944/100000
# 	episodic returns: -171.29 +/- 5.63
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 110/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 83712/100000
# 	episodic returns: -173.39 +/- 8.30
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 111/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 84480/100000
# 	episodic returns: -173.53 +/- 9.91
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 112/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 85248/100000
# 	episodic returns: -173.36 +/- 7.93
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 113/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 86016/100000
# 	episodic returns: -168.01 +/- 3.29
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 114/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 86784/100000
# 	episodic returns: -171.04 +/- 5.76
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 115/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 87552/100000
# 	episodic returns: -171.96 +/- 8.55
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 116/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 88320/100000
# 	episodic returns: -172.72 +/- 8.18
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 117/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 89088/100000
# 	episodic returns: -169.52 +/- 4.49
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 118/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 89856/100000
# 	episodic returns: -170.36 +/- 5.06
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 119/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 90624/100000
# 	episodic returns: -167.93 +/- 3.70
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 120/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 91392/100000
# 	episodic returns: -167.90 +/- 3.24
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 121/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 92160/100000
# 	episodic returns: -168.40 +/- 4.86
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 122/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 92928/100000
# 	episodic returns: -169.36 +/- 7.77
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 123/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 93696/100000
# 	episodic returns: -167.14 +/- 6.44
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 124/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 94464/100000
# 	episodic returns: -165.64 +/- 4.13
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 125/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 95232/100000
# 	episodic returns: -167.78 +/- 3.73
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 126/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 96000/100000
# 	episodic returns: -170.54 +/- 5.32
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 127/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 96768/100000
# 	episodic returns: -169.52 +/- 5.70
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 128/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 97536/100000
# 	episodic returns: -165.34 +/- 2.65
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 129/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 98304/100000
# 	episodic returns: -168.10 +/- 6.44
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113
# INFO:rl_trainer.ppo.ppo_trainer:iteration 130/130
# INFO:rl_trainer.ppo.ppo_trainer:Last 10 episodes:
# 	global step: 99072/100000
# 	episodic returns: -174.45 +/- 8.75
# 	episodic costs: 0.00 +/- 0.00
# 	episodic lengths: 100.00 +/- 0.00
#
# INFO:rl_trainer.ppo.ppo_trainer:SPS: 113

# %%
import matplotlib.pyplot as plt

train_steps = results["train_steps"]
train_returns = results["train_returns"]
train_costs = results["train_costs"]

# group by steps (possible duplicate in steps due to vectorization)
train_steps, train_returns, train_returns_std, train_costs, train_costs_std = zip(*sorted(
    [(step, 
      np.mean([r for r, s in zip(train_returns, train_steps) if s == step]), 
      np.std([r for r, s in zip(train_returns, train_steps) if s == step]),
      np.mean([c for c, s in zip(train_costs, train_steps) if s == step]),
      np.std([c for c, s in zip(train_costs, train_steps) if s == step])) for step in set(train_steps)]
))

fig, axes = plt.subplots(1, 2, figsize=(15, 5))

axes[0].plot(train_steps, train_returns)
axes[0].fill_between(train_steps, np.array(train_returns) - np.array(train_returns_std), np.array(train_returns) + np.array(train_returns_std), alpha=0.2)
axes[0].set_xlabel("Steps")
axes[0].set_title("Episodic Return")

axes[1].plot(train_steps, train_costs)
axes[1].fill_between(train_steps, np.array(train_costs) - np.array(train_costs_std), np.array(train_costs) + np.array(train_costs_std), alpha=0.2)
axes[1].set_xlabel("Steps")
axes[1].set_title("Episodic Cost")

plt.show()

# %%
eval_envs = gym.vector.SyncVectorEnv([make_env(seed=seed, render_mode='rgb_array') for i in range(1)])
agent = trainer.get_actor()

obs, infos = eval_envs.reset()
done = False
frames = []
while not done:
    action = agent.get_action_and_value(torch.Tensor(obs).to(device))["action"]
    obs, reward, term, trunc, infos = eval_envs.step(action.detach().cpu().numpy())
    done = term[0] or trunc[0]
    frame = eval_envs.envs[0].render()
    frames.append(frame)

# %%
# save gif
import imageio
imageio.mimsave("safe_robust_policy.mp4", frames, fps=10)

# %% [markdown]
# <video controls src="safe_policy.mp4">animation</video>

# %%
from IPython.display import Video

Video("safe_robust_policy.mp4")
# Out:
# <video src="safe_robust_policy.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
